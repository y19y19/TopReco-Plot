# %% [markdown]
# # Save np array for Run 2 (2017 does not save Transformer inference result as it contains training events)

# %%
import numpy as np
import Utilities.LoadData_Run2

# %%
gen_top, mlb_top, tf_top, weight, filter_mlb = Utilities.LoadData_Run2.getAllData(process_eras=['2016preVFP', '2016postVFP'])
# Out:
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalviatau_fromDilepton_2016ULpreVFP_11.root
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalviatau_fromDilepton_2016ULpreVFP_15.root
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalviatau_fromDilepton_2016ULpreVFP_0.root
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_6.root
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalviatau_fromDilepton_2016ULpreVFP_9.root
# /depot/cms/users/jduarteq/2016preVFP/spinCorrInput_2016preVFP_November2024/Nominal/ee//ee_ttbarsignalviatau_fromDilepton_2016ULpreVFP_18.root
# ...

# %%
save_folder = f"../arrays"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# %%
for era, _list in gen_top.items():
    np.save(f"{save_folder}/{era}/target_top_px.npy", gen_top[era][:,0])
    np.save(f"{save_folder}/{era}/target_top_py.npy", gen_top[era][:,2])
    np.save(f"{save_folder}/{era}/target_top_pz.npy", gen_top[era][:,4])
    np.save(f"{save_folder}/{era}/target_top_energy.npy", gen_top[era][:,6])
    np.save(f"{save_folder}/{era}/target_topbar_px.npy", gen_top[era][:,1])
    np.save(f"{save_folder}/{era}/target_topbar_py.npy", gen_top[era][:,3])
    np.save(f"{save_folder}/{era}/target_topbar_pz.npy", gen_top[era][:,5])
    np.save(f"{save_folder}/{era}/target_topbar_energy.npy", gen_top[era][:,7])

# %%
for era, _list in mlb_top.items():
    np.save(f"{save_folder}/{era}/mlb_top_px.npy", mlb_top[era][:,0])
    np.save(f"{save_folder}/{era}/mlb_top_py.npy", mlb_top[era][:,2])
    np.save(f"{save_folder}/{era}/mlb_top_pz.npy", mlb_top[era][:,4])
    np.save(f"{save_folder}/{era}/mlb_top_energy.npy", mlb_top[era][:,6])
    np.save(f"{save_folder}/{era}/mlb_topbar_px.npy", mlb_top[era][:,1])
    np.save(f"{save_folder}/{era}/mlb_topbar_py.npy", mlb_top[era][:,3])
    np.save(f"{save_folder}/{era}/mlb_topbar_pz.npy", mlb_top[era][:,5])
    np.save(f"{save_folder}/{era}/mlb_topbar_energy.npy", mlb_top[era][:,7])

# %%
for era, _list in tf_top.items():
    np.save(f"{save_folder}/{era}/transformer_top_px.npy", tf_top[era][:,0])
    np.save(f"{save_folder}/{era}/transformer_top_py.npy", tf_top[era][:,2])
    np.save(f"{save_folder}/{era}/transformer_top_pz.npy", tf_top[era][:,4])
    np.save(f"{save_folder}/{era}/transformer_top_energy.npy", tf_top[era][:,6])
    np.save(f"{save_folder}/{era}/transformer_topbar_px.npy", tf_top[era][:,1])
    np.save(f"{save_folder}/{era}/transformer_topbar_py.npy", tf_top[era][:,3])
    np.save(f"{save_folder}/{era}/transformer_topbar_pz.npy", tf_top[era][:,5])
    np.save(f"{save_folder}/{era}/transformer_topbar_energy.npy", tf_top[era][:,7])

# %%
for era, _list in weight.items():
    np.save(f"{save_folder}/{era}/weight.npy", weight[era])

for era, _list in filter_mlb.items():
    np.save(f"{save_folder}/{era}/mlb_filter.npy", filter_mlb[era])
